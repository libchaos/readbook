# %%
from IPython.display import Image

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5qp40szgj21020oowil.jpg', width=600)

# %% [markdown]
# store 每次存隐含层的输出结果

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5x2bhekbj20f40qodh8.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5rwfydg8j20z40ncgpx.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5r7kqq1lj20zi0o2jtf.jpg', width=600)

# %% [markdown]
# 最单纯的memory

# %% [markdown]
# LSTM

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5s8gyp2sj21mc170guz.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5vb6343ej21040s00wg.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5vmeii21j20f40qo0ue.jpg', width=400)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5vwnmb2nj20f40qojt3.jpg')

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5wgxvccij211g0qstce.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5wmw68omj211s0qewij.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5x9vmg8kj215m0r4dib.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5xd0u8j4j21ns14cgrw.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5xee7ql2j214c0o8776.jpg', width=600)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5xi9giqtj20ye0nmdjn.jpg', width=800)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5xjareztj21900p00wz.jpg', width=800)

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5xgwui6yj20yy0q2wi4.jpg', width=600)

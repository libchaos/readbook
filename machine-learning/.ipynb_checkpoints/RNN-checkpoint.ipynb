# %%
from IPython.display import Image

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5qp40szgj21020oowil.jpg', width=600)

# %% [markdown]
# store 每次存隐含层的输出结果

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1fm5r7kqq1lj20zi0o2jtf.jpg', width=600)

# %% [markdown]
# 最单纯的memory

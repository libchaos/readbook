# %% [markdown]
# ## 词袋模型(BOW)

# %%
from IPython.display import Image

# %%
Image('http://ww1.sinaimg.cn/large/9e58a4edly1flwptrstwjj21b60m2mzu.jpg', width=600)

# %% [markdown]
# 词袋模型: 像是句子或是文件这样的文字可以用一个袋子装着这些词的方式表现，这种表现方式不考虑文法以及词的顺序。
# (1) John likes to watch movies. Mary likes movies too.
# (2) John also likes to watch football games.
# 基于以上两个文件，可以建构出下列清单:
# [
#     "John",
#     "likes",
#     "to",
#     "watch",
#     "movies",
#     "also",
#     "football",
#     "games",
#     "Mary",
#     "too"
# ]
# 此处有10个不同的词，使用清单的索引表示长度为10的向量:
#
# (1) [1, 2, 1, 1, 2, 0, 0, 0, 1, 1] (2) [1, 1, 1, 1, 0, 1, 1, 1, 0, 0]
# 每个向量的索引内容对应到清单中词出现的次数。
